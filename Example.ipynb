# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import math

# %%
print("Hello Bose!")
# Out:
# Hello Bose!

# %%
a = 1.0
b = np.zeros(10)
c = np.zeros(10)

for i in range(10):
    c[i] = i
    b[i] = a + math.sin(i)
    print(b[i])

    
x = np.linspace(0, 20, 1000)  # 100 evenly-spaced values from 0 to 50
y = np.sin(x)

plt.plot(x,y)
# Out:
# 1.0
# 1.84147098481
# 1.90929742683
# 1.14112000806
# 0.243197504692
# 0.0410757253369
# 0.720584501801
# 1.65698659872
# 1.98935824662
# 1.41211848524

# %%
plt.plot(c,b)
