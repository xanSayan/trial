# %%
for i in range (2):
    for j in range (i):
        print("fff")
# Out:
# fff

# %%
import math

# %%
print(math.sin(33))
# Out:
# 0.9999118601072672

# %%
print("Some change")
# Out:
# Some change

# %%
print("Welcome to the jungle *_*")
# Out:
# Welcome to the jungle *_*

# %%
import time
print("start")

print("enmmmm")
# Out:
# start
# enmmmm

# %%
print(math.cos(1123))
# Out:
# -0.11909034644975776

# %%
print(33)
# Out:
# 33

# %%
print("IDK")
# Out:
# IDK
