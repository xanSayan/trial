# %%
for i in range (6):
    for j in range (i):
        print("*")
# Out:
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *

# %%
import math

# %%
print(math.sin(77))
# Out:
# 0.9995201585807313

# %%
print("Some change")
# Out:
# Some change

# %%
print("Welcome to the jungle *_*")
# Out:
# Welcome to the jungle *_*

# %%
import time
print("start")
time.sleep(120)
print("enmmmm")
# Out:
# start
