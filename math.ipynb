# %%
print(4*7)
# Out:
# 28

# %%
print(3*3)
# Out:
# 9

# %%
print(34*9)
# Out:
# 306

# %%
import os

# %%
print(os.getcwd())
# Out:
# /home/cloak/trial

# %%
os.chdir("/home/cloak/SayanBose/")
print(os.getcwd())
# Out:
# /home/cloak/SayanBose

# %%
print("schalf schon ssdsdsds")
# Out:
# schalf schon ssdsdsds

# %%
print(os.getcwd())
# Out:
# C:\Users\sayan\trial

# %%
print("BOSE-XAN-POL2")
# Out:
# BOSE-XAN-POL2

# %%
print(232323+434343)
# Out:
# 666666
