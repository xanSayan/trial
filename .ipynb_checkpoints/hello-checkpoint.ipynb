# %%
print("Hello")
# Out:
# Hello

# %%
print("Another Hmmmello oooooooooo")
# Out:
# Another Hmmmello oooooooooo

# %%
print(6*4)
# Out:
# 24

# %%
print("Dont know why?")
# Out:
# Dont know why?

# %%
print("While my guitar gently weeps")
# Out:
# While my guitar gently weeps

# %%
print(45*40)
# Out:
# 1800
